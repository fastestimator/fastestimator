# %% [markdown]
# # Breast Cancer Detection
#
# [[Notebook](https://github.com/fastestimator/fastestimator/blob/master/apphub/tabular/dnn/dnn.ipynb)] [[Torch Implementation](https://github.com/fastestimator/fastestimator/blob/master/apphub/tabular/dnn/dnn_torch.py)]

# %% [markdown]
# ## Import the required libraries

# %%
import tempfile

import fastestimator as fe
from fastestimator.dataset.data import breast_cancer
from fastestimator.op.tensorop.loss import CrossEntropy
from fastestimator.op.tensorop.model import ModelOp, UpdateOp
from fastestimator.trace.io import BestModelSaver
from fastestimator.trace.metric import Accuracy
# Out:
# 2025-04-08 19:46:59.522154: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-08 19:46:59.557135: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-08 19:46:59.557159: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-08 19:46:59.558608: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-08 19:46:59.565734: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-08 19:47:00.231844: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# We import these in a separate block to avoid an import error in Jupyter when running on Linux CPU-only machines
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as fn
from sklearn.preprocessing import StandardScaler

# %%
#training parameters
batch_size = 4
epochs = 10
save_dir = tempfile.mkdtemp()
train_steps_per_epoch = None
eval_steps_per_epoch = None

# %% [markdown]
# # Download data

# %% [markdown]
# This downloads some tabular data with different features stored in numerical format in a table. We then split the data into train, evaluation, and testing data sets.

# %%
train_data, eval_data = breast_cancer.load_data()
test_data = eval_data.split(0.5)

# %% [markdown]
# This is what the raw data looks like:

# %%
df = pd.DataFrame.from_dict(train_data.data, orient='index')
df.head()
# Out:
#                                                    x  y
# 0  [9.029, 17.33, 58.79, 250.5, 0.1066, 0.1413, 0...  1
# 1  [21.09, 26.57, 142.7, 1311.0, 0.1141, 0.2832, ...  0
# 2  [9.173, 13.86, 59.2, 260.9, 0.07721, 0.08751, ...  1
# 3  [10.65, 25.22, 68.01, 347.0, 0.09657, 0.07234,...  1
# 4  [10.17, 14.88, 64.55, 311.9, 0.1134, 0.08061, ...  1

# %%
scaler = StandardScaler()
train_data["x"] = scaler.fit_transform(train_data["x"])
eval_data["x"] = scaler.transform(eval_data["x"])
test_data["x"] = scaler.transform(test_data["x"])

# %% [markdown]
# # Building Components

# %% [markdown]
# ## Step 1: Create `Pipeline`

# %% [markdown]
# We create the `Pipeline` with the usual train, eval, and test data along with the batch size:

# %%
pipeline = fe.Pipeline(train_data=train_data, eval_data=eval_data, test_data=test_data, batch_size=batch_size)

# %% [markdown]
# ## Step 2: Create `Network`

# %% [markdown]
# We first define the neural network in a function that can then be passed on to the FastEstimator `Network`:

# %%
class DNN(torch.nn.Module):
    def __init__(self, num_inputs=30, n_outputs=1):
        super().__init__()
        self.fc1 = nn.Linear(num_inputs, 32)
        self.dp1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(32, 16)
        self.dp2 = nn.Dropout(0.5)
        self.fc3 = nn.Linear(16, 8)
        self.dp3 = nn.Dropout(0.5)
        self.fc4 = nn.Linear(8, n_outputs)

    def forward(self, x):
        x = self.fc1(x)
        x = fn.relu(x)
        x = self.dp1(x)
        x = self.fc2(x)
        x = fn.relu(x)
        x = self.dp2(x)
        x = self.fc3(x)
        x = fn.relu(x)
        x = self.dp3(x)
        x = self.fc4(x)
        x = torch.sigmoid(x)
        return x

# %%
model = fe.build(model_fn=DNN, optimizer_fn="adam")
network = fe.Network(ops=[
    ModelOp(inputs="x", model=model, outputs="y_pred"),
    CrossEntropy(inputs=("y_pred", "y"), outputs="ce"),
    UpdateOp(model=model, loss_name="ce")
])

# %% [markdown]
# ## Step 3: Create `Estimator`

# %%
traces = [
    Accuracy(true_key="y", pred_key="y_pred"),
    BestModelSaver(model=model, save_dir=save_dir, metric="accuracy", save_best_mode="max")
]
estimator = fe.Estimator(pipeline=pipeline,
                         network=network,
                         epochs=epochs,
                         log_steps=10,
                         traces=traces,
                         train_steps_per_epoch=train_steps_per_epoch,
                         eval_steps_per_epoch=eval_steps_per_epoch)

# %% [markdown]
# # Training

# %%
estimator.fit()
# Out:
#     ______           __  ______     __  _                 __
#    / ____/___ ______/ /_/ ____/____/ /_(_)___ ___  ____ _/ /_____  _____
#   / /_  / __ `/ ___/ __/ __/ / ___/ __/ / __ `__ \/ __ `/ __/ __ \/ ___/
#  / __/ / /_/ (__  ) /_/ /___(__  ) /_/ / / / / / / /_/ / /_/ /_/ / /
# /_/    \__,_/____/\__/_____/____/\__/_/_/ /_/ /_/\__,_/\__/\____/_/
#
#
# FastEstimator-Start: step: 1; logging_interval: 10; num_device: 1;
# FastEstimator-Train: step: 1; ce: 0.6862113;
# FastEstimator-Train: step: 10; ce: 0.7020595; steps/sec: 102.86;
# FastEstimator-Train: step: 20; ce: 0.70628023; steps/sec: 531.16;
# FastEstimator-Train: step: 30; ce: 0.7030227; steps/sec: 535.64;
# FastEstimator-Train: step: 40; ce: 0.67554265; steps/sec: 439.23;
# FastEstimator-Train: step: 50; ce: 0.6286818; steps/sec: 525.02;
# FastEstimator-Train: step: 60; ce: 0.6837653; steps/sec: 531.95;
# FastEstimator-Train: step: 70; ce: 0.65377337; steps/sec: 404.09;
# FastEstimator-Train: step: 80; ce: 0.6911675; steps/sec: 364.0;
# FastEstimator-Train: step: 90; ce: 0.6422817; steps/sec: 377.94;
# FastEstimator-Train: step: 100; ce: 0.62393796; steps/sec: 343.32;
# FastEstimator-Train: step: 110; ce: 0.6486562; steps/sec: 377.48;
# FastEstimator-Train: step: 114; epoch: 1; epoch_time(sec): 1.32;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 55.38;
# Eval Progress: 10/15; steps/sec: 998.64;
# Eval Progress: 15/15; steps/sec: 536.79;
# FastEstimator-BestModelSaver: Saved model to /tmp/tmpv8034bc3/model_best_accuracy.pt
# FastEstimator-Eval: step: 114; epoch: 1; accuracy: 0.7719298245614035; ce: 0.61699396; max_accuracy: 0.7719298245614035; since_best_accuracy: 0;
# FastEstimator-Train: step: 120; ce: 0.6097033; steps/sec: 10.1;
# FastEstimator-Train: step: 130; ce: 0.616711; steps/sec: 443.75;
# FastEstimator-Train: step: 140; ce: 0.5692897; steps/sec: 441.69;
# FastEstimator-Train: step: 150; ce: 0.7007519; steps/sec: 494.55;
# FastEstimator-Train: step: 160; ce: 0.69924855; steps/sec: 470.73;
# FastEstimator-Train: step: 170; ce: 0.45609045; steps/sec: 485.25;
# FastEstimator-Train: step: 180; ce: 0.5789407; steps/sec: 489.06;
# FastEstimator-Train: step: 190; ce: 0.10101885; steps/sec: 339.22;
# FastEstimator-Train: step: 200; ce: 0.6303601; steps/sec: 331.23;
# FastEstimator-Train: step: 210; ce: 0.6809145; steps/sec: 325.24;
# FastEstimator-Train: step: 220; ce: 0.5318433; steps/sec: 335.46;
# FastEstimator-Train: step: 228; epoch: 2; epoch_time(sec): 1.23;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 58.33;
# Eval Progress: 10/15; steps/sec: 975.27;
# Eval Progress: 15/15; steps/sec: 975.72;
# FastEstimator-BestModelSaver: Saved model to /tmp/tmpv8034bc3/model_best_accuracy.pt
# FastEstimator-Eval: step: 228; epoch: 2; accuracy: 0.9649122807017544; ce: 0.33739504; max_accuracy: 0.9649122807017544; since_best_accuracy: 0;
# FastEstimator-Train: step: 230; ce: 0.50650764; steps/sec: 10.68;
# FastEstimator-Train: step: 240; ce: 0.22836189; steps/sec: 117.47;
# FastEstimator-Train: step: 250; ce: 0.37539157; steps/sec: 497.37;
# FastEstimator-Train: step: 260; ce: 1.0229278; steps/sec: 506.27;
# FastEstimator-Train: step: 270; ce: 0.12797047; steps/sec: 449.11;
# FastEstimator-Train: step: 280; ce: 0.59197915; steps/sec: 494.84;
# FastEstimator-Train: step: 290; ce: 0.05541705; steps/sec: 493.61;
# FastEstimator-Train: step: 300; ce: 0.25546375; steps/sec: 388.54;
# FastEstimator-Train: step: 310; ce: 0.35834843; steps/sec: 349.75;
# FastEstimator-Train: step: 320; ce: 0.41919413; steps/sec: 349.65;
# FastEstimator-Train: step: 330; ce: 0.31453943; steps/sec: 324.55;
# FastEstimator-Train: step: 340; ce: 0.2076896; steps/sec: 343.13;
# FastEstimator-Train: step: 342; epoch: 3; epoch_time(sec): 1.26;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 48.09;
# Eval Progress: 10/15; steps/sec: 1103.9;
# Eval Progress: 15/15; steps/sec: 1108.45;
# FastEstimator-Eval: step: 342; epoch: 3; accuracy: 0.9649122807017544; ce: 0.18042034; max_accuracy: 0.9649122807017544; since_best_accuracy: 1;
# FastEstimator-Train: step: 350; ce: 0.22867581; steps/sec: 9.91;
# FastEstimator-Train: step: 360; ce: 0.20051655; steps/sec: 466.89;
# FastEstimator-Train: step: 370; ce: 1.0317225; steps/sec: 500.33;
# FastEstimator-Train: step: 380; ce: 0.19244099; steps/sec: 446.36;
# FastEstimator-Train: step: 390; ce: 0.27535257; steps/sec: 494.84;
# FastEstimator-Train: step: 400; ce: 0.2786669; steps/sec: 493.85;
# FastEstimator-Train: step: 410; ce: 0.34420234; steps/sec: 398.42;
# FastEstimator-Train: step: 420; ce: 0.37158805; steps/sec: 366.01;
# FastEstimator-Train: step: 430; ce: 0.16807215; steps/sec: 334.38;
# FastEstimator-Train: step: 440; ce: 0.009761098; steps/sec: 327.19;
# FastEstimator-Train: step: 450; ce: 0.18035656; steps/sec: 357.96;
# FastEstimator-Train: step: 456; epoch: 4; epoch_time(sec): 1.26;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 55.29;
# Eval Progress: 10/15; steps/sec: 991.41;
# Eval Progress: 15/15; steps/sec: 1051.55;
# FastEstimator-BestModelSaver: Saved model to /tmp/tmpv8034bc3/model_best_accuracy.pt
# FastEstimator-Eval: step: 456; epoch: 4; accuracy: 0.9824561403508771; ce: 0.101917066; max_accuracy: 0.9824561403508771; since_best_accuracy: 0;
# FastEstimator-Train: step: 460; ce: 0.21341965; steps/sec: 10.32;
# FastEstimator-Train: step: 470; ce: 0.13672113; steps/sec: 161.84;
# FastEstimator-Train: step: 480; ce: 0.33030415; steps/sec: 431.05;
# FastEstimator-Train: step: 490; ce: 0.4560606; steps/sec: 478.44;
# FastEstimator-Train: step: 500; ce: 0.017378634; steps/sec: 445.54;
# FastEstimator-Train: step: 510; ce: 0.00060683535; steps/sec: 479.04;
# FastEstimator-Train: step: 520; ce: 0.92226505; steps/sec: 483.49;
# FastEstimator-Train: step: 530; ce: 0.4894778; steps/sec: 361.32;
# FastEstimator-Train: step: 540; ce: 0.9509631; steps/sec: 325.79;
# FastEstimator-Train: step: 550; ce: 0.21884987; steps/sec: 333.79;
# FastEstimator-Train: step: 560; ce: 0.40062276; steps/sec: 331.5;
# FastEstimator-Train: step: 570; ce: 0.29765677; steps/sec: 341.32;
# FastEstimator-Train: step: 570; epoch: 5; epoch_time(sec): 1.28;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 42.79;
# Eval Progress: 10/15; steps/sec: 1197.81;
# Eval Progress: 15/15; steps/sec: 1125.17;
# FastEstimator-Eval: step: 570; epoch: 5; accuracy: 0.9824561403508771; ce: 0.09493221; max_accuracy: 0.9824561403508771; since_best_accuracy: 1;
# FastEstimator-Train: step: 580; ce: 0.47475797; steps/sec: 9.79;
# FastEstimator-Train: step: 590; ce: 0.075305305; steps/sec: 465.09;
# FastEstimator-Train: step: 600; ce: 0.21077634; steps/sec: 496.53;
# FastEstimator-Train: step: 610; ce: 0.18742286; steps/sec: 455.47;
# FastEstimator-Train: step: 620; ce: 0.014598275; steps/sec: 494.87;
# FastEstimator-Train: step: 630; ce: 0.040610876; steps/sec: 498.8;
# FastEstimator-Train: step: 640; ce: 0.28375545; steps/sec: 434.33;
# FastEstimator-Train: step: 650; ce: 0.025458004; steps/sec: 353.23;
# FastEstimator-Train: step: 660; ce: 0.032360066; steps/sec: 310.31;
# FastEstimator-Train: step: 670; ce: 0.1303002; steps/sec: 328.17;
# FastEstimator-Train: step: 680; ce: 0.34880012; steps/sec: 344.31;
# FastEstimator-Train: step: 684; epoch: 6; epoch_time(sec): 1.28;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 96.5;
# Eval Progress: 10/15; steps/sec: 1009.73;
# Eval Progress: 15/15; steps/sec: 1017.17;
# FastEstimator-Eval: step: 684; epoch: 6; accuracy: 0.9824561403508771; ce: 0.09596362; max_accuracy: 0.9824561403508771; since_best_accuracy: 2;
# FastEstimator-Train: step: 690; ce: 0.008805074; steps/sec: 9.89;
# FastEstimator-Train: step: 700; ce: 0.039518822; steps/sec: 466.72;
# FastEstimator-Train: step: 710; ce: 0.20936926; steps/sec: 492.88;
# FastEstimator-Train: step: 720; ce: 0.3645945; steps/sec: 460.74;
# FastEstimator-Train: step: 730; ce: 0.03392948; steps/sec: 496.28;
# FastEstimator-Train: step: 740; ce: 0.05268296; steps/sec: 484.6;
# FastEstimator-Train: step: 750; ce: 0.1528996; steps/sec: 492.0;
# FastEstimator-Train: step: 760; ce: 0.005272494; steps/sec: 344.37;
# FastEstimator-Train: step: 770; ce: 0.17312968; steps/sec: 332.53;
# FastEstimator-Train: step: 780; ce: 0.0444039; steps/sec: 330.3;
# FastEstimator-Train: step: 790; ce: 0.37767485; steps/sec: 341.6;
# FastEstimator-Train: step: 798; epoch: 7; epoch_time(sec): 1.26;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 46.0;
# Eval Progress: 10/15; steps/sec: 1001.06;
# Eval Progress: 15/15; steps/sec: 965.15;
# FastEstimator-Eval: step: 798; epoch: 7; accuracy: 0.9824561403508771; ce: 0.09472351; max_accuracy: 0.9824561403508771; since_best_accuracy: 3;
# FastEstimator-Train: step: 800; ce: 0.2752872; steps/sec: 10.7;
# FastEstimator-Train: step: 810; ce: 0.008222078; steps/sec: 124.63;
# FastEstimator-Train: step: 820; ce: 0.0049030697; steps/sec: 488.77;
# FastEstimator-Train: step: 830; ce: 0.161672; steps/sec: 480.76;
# FastEstimator-Train: step: 840; ce: 0.09381053; steps/sec: 473.82;
# FastEstimator-Train: step: 850; ce: 0.04670338; steps/sec: 491.11;
# FastEstimator-Train: step: 860; ce: 0.09513493; steps/sec: 493.32;
# FastEstimator-Train: step: 870; ce: 0.3014415; steps/sec: 367.16;
# FastEstimator-Train: step: 880; ce: 0.35180998; steps/sec: 337.01;
# FastEstimator-Train: step: 890; ce: 0.017161133; steps/sec: 336.83;
# FastEstimator-Train: step: 900; ce: 0.018704344; steps/sec: 319.31;
# FastEstimator-Train: step: 910; ce: 0.07550951; steps/sec: 326.43;
# FastEstimator-Train: step: 912; epoch: 8; epoch_time(sec): 1.26;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 44.57;
# Eval Progress: 10/15; steps/sec: 1023.43;
# Eval Progress: 15/15; steps/sec: 981.09;
# FastEstimator-Eval: step: 912; epoch: 8; accuracy: 0.9824561403508771; ce: 0.08927895; max_accuracy: 0.9824561403508771; since_best_accuracy: 4;
# FastEstimator-Train: step: 920; ce: 0.06492483; steps/sec: 9.83;
# FastEstimator-Train: step: 930; ce: 0.16755788; steps/sec: 466.77;
# FastEstimator-Train: step: 940; ce: 0.9286219; steps/sec: 490.01;
# FastEstimator-Train: step: 950; ce: 0.003220613; steps/sec: 443.73;
# FastEstimator-Train: step: 960; ce: 0.09299693; steps/sec: 501.2;
# FastEstimator-Train: step: 970; ce: 0.20747614; steps/sec: 485.27;
# FastEstimator-Train: step: 980; ce: 0.03271385; steps/sec: 456.42;
# FastEstimator-Train: step: 990; ce: 0.0049211937; steps/sec: 347.92;
# FastEstimator-Train: step: 1000; ce: 0.00023653766; steps/sec: 342.16;
# FastEstimator-Train: step: 1010; ce: 0.1705307; steps/sec: 316.4;
# FastEstimator-Train: step: 1020; ce: 0.22545597; steps/sec: 343.7;
# FastEstimator-Train: step: 1026; epoch: 9; epoch_time(sec): 1.28;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 59.46;
# Eval Progress: 10/15; steps/sec: 1056.86;
# Eval Progress: 15/15; steps/sec: 1056.27;
# FastEstimator-Eval: step: 1026; epoch: 9; accuracy: 0.9824561403508771; ce: 0.09008657; max_accuracy: 0.9824561403508771; since_best_accuracy: 5;
# FastEstimator-Train: step: 1030; ce: 0.0013508502; steps/sec: 9.82;
# FastEstimator-Train: step: 1040; ce: 0.23784843; steps/sec: 158.93;
# FastEstimator-Train: step: 1050; ce: 0.0030006832; steps/sec: 498.75;
# FastEstimator-Train: step: 1060; ce: 0.16162261; steps/sec: 498.57;
# FastEstimator-Train: step: 1070; ce: 0.019650403; steps/sec: 464.49;
# FastEstimator-Train: step: 1080; ce: 0.00015102944; steps/sec: 489.7;
# FastEstimator-Train: step: 1090; ce: 0.006012914; steps/sec: 497.06;
# FastEstimator-Train: step: 1100; ce: 0.04267344; steps/sec: 360.7;
# FastEstimator-Train: step: 1110; ce: 0.056002665; steps/sec: 330.79;
# FastEstimator-Train: step: 1120; ce: 0.34145764; steps/sec: 322.7;
# FastEstimator-Train: step: 1130; ce: 0.1866588; steps/sec: 305.39;
# FastEstimator-Train: step: 1140; ce: 0.003093163; steps/sec: 344.38;
# FastEstimator-Train: step: 1140; epoch: 10; epoch_time(sec): 1.32;
# Eval Progress: 1/15;
# Eval Progress: 5/15; steps/sec: 59.19;
# Eval Progress: 10/15; steps/sec: 778.07;
# Eval Progress: 15/15; steps/sec: 893.77;
# FastEstimator-Eval: step: 1140; epoch: 10; accuracy: 0.9824561403508771; ce: 0.08675402; max_accuracy: 0.9824561403508771; since_best_accuracy: 6;
# FastEstimator-Finish: step: 1140; model_lr: 0.001; total_time(sec): 23.03;

# %% [markdown]
# ## Model testing
# `Estimator.test` triggers model testing with the test dataset that was specified in our `Pipeline`. We can use this to evaluate our model's accuracy on previously unseen data:

# %%
estimator.test()
# Out:
# FastEstimator-Test: step: 1140; epoch: 10; accuracy: 0.9824561403508771; ce: 0.05191838;
